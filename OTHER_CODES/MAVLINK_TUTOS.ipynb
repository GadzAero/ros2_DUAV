# %%
from pymavlink import mavutil

import time
import sys


# BASE SUR LE SITE
# https://www.ardusub.com/developers/pymavlink.html#send-rc-joystick

# %% [markdown]
# Voila ce que vous retrouverez sur ce lien :
# - Autopilot (E.g: Pixhawk) connected to the computer via serial
# - Run pyMavlink on the surface computer
# - Run pyMavlink on the companion computer
# - Send Message to QGroundControl
# - Arm/Disarm the vehicle
# - Change flight mode
# - Send RC (Joystick)
# - Send Manual Control
# - Read all parameters
# - Read and write parameters
# - Receive data and filter by message type
# - Request message interval
# - Control Camera Gimbal
# - Set Servo PWM
# - Advanced Servo/Gripper Example
# - Set Target Depth/Attitude
# - Send GPS position
# - Send rangefinder/computer vision distance measurement to the autopilot

# %% [markdown]
# ### Connect to the SIM

# %%
master = mavutil.mavlink_connection('tcp:127.0.0.1:5762')  # Adjust IP and port if needed
print("Waiting for heartbeat...")
master.wait_heartbeat()
print("Heartbeat received! System ready.")
# Out:
# Waiting for heartbeat...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 3
#       1 master = mavutil.mavlink_connection('tcp:127.0.0.1:5762')  # Adjust IP and port if needed
#       2 print("Waiting for heartbeat...")
# ----> 3 master.wait_heartbeat()
#       4 print("Heartbeat received! System ready.")
#
# File ~/.local/lib/python3.10/site-packages/pymavlink/mavutil.py:559, in mavfile.wait_heartbeat(self, blocking, timeout)
#     557 def wait_heartbeat(self, blocking=True, timeout=None):
#     558     '''wait for a heartbeat so we know the target system IDs'''
# --> 559     return self.recv_match(type='HEARTBEAT', blocking=blocking, timeout=timeout)
#
# File ~/.local/lib/python3.10/site-packages/pymavlink/mavutil.py:526, in mavfile.recv_match(self, condition, type, blocking, timeout)
#     524     hook(self)
#     525 if timeout is None:
# --> 526     self.select(0.05)
#     527 else:
#     528     self.select(timeout/2)
#
# File ~/.local/lib/python3.10/site-packages/pymavlink/mavutil.py:339, in mavfile.select(self, timeout)
#     337     return True
#     338 try:
# --> 339     (rin, win, xin) = select.select([self.fd], [], [], timeout)
#     340 except select.error:
#     341     return False
#
# KeyboardInterrupt:

# %% [markdown]
# ### Wait for a ping

# %%
def wait_conn():
    """
    Sends a ping to stabilish the UDP communication and awaits for a response
    """
    msg = None
    while not msg:
        master.mav.ping_send(
            int(time.time() * 1e6), # Unix time in microseconds
            0, # Ping number
            0, # Request ping of all systems
            0 # Request ping of all components
        )
        msg = master.recv_match()
        time.sleep(0.5)

wait_conn()

print("Ping recu")
# Out:
# Ping recu

# %% [markdown]
# ### Print every msg

# %%
for i in range(10):
    try:
        print(master.recv_match().to_dict())
    except:
        pass
    time.sleep(0.1)
# Out:
# {'mavpackettype': 'SYS_STATUS', 'onboard_control_sensors_present': 1399979055, 'onboard_control_sensors_enabled': 1382128687, 'onboard_control_sensors_health': 1467063343, 'load': 0, 'voltage_battery': 12600, 'current_battery': 0, 'battery_remaining': 100, 'drop_rate_comm': 0, 'errors_comm': 0, 'errors_count1': 0, 'errors_count2': 0, 'errors_count3': 0, 'errors_count4': 0}
# {'mavpackettype': 'GPS_GLOBAL_ORIGIN', 'latitude': -353632621, 'longitude': 1491652374, 'altitude': 584090, 'time_usec': 49189483}
# {'mavpackettype': 'HOME_POSITION', 'latitude': -353632621, 'longitude': 1491652374, 'altitude': 584090, 'x': 0.0, 'y': 0.0, 'z': -0.0, 'q': [nan, nan, nan, nan], 'approach_x': 0.0, 'approach_y': 0.0, 'approach_z': 0.0, 'time_usec': 49189483}
# {'mavpackettype': 'PING', 'time_usec': 1737053172488433, 'seq': 0, 'target_system': 0, 'target_component': 0}
# {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
# {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
# {'mavpackettype': 'TERRAIN_DATA', 'lat': -353747690, 'lon': 1491238739, 'grid_spacing': 100, 'gridbit': 0, 'data': [787, 787, 773, 753, 786, 787, 768, 742, 786, 780, 753, 729, 783, 774, 746, 722]}
# {'mavpackettype': 'TERRAIN_DATA', 'lat': -353747690, 'lon': 1491238739, 'grid_spacing': 100, 'gridbit': 0, 'data': [769, 782, 775, 749, 783, 789, 764, 738, 778, 776, 743, 725, 775, 775, 742, 719]}
# {'mavpackettype': 'TERRAIN_DATA', 'lat': -353747690, 'lon': 1491238739, 'grid_spacing': 100, 'gridbit': 1, 'data': [720, 695, 687, 675, 712, 692, 685, 675, 704, 691, 685, 676, 704, 689, 685, 678]}
# {'mavpackettype': 'TERRAIN_DATA', 'lat': -353747690, 'lon': 1491238739, 'grid_spacing': 100, 'gridbit': 2, 'data': [672, 672, 675, 681, 674, 679, 673, 679, 681, 680, 678, 677, 677, 674, 676, 672]}

# %% [markdown]
# ### Send a message to QGroundControl

# %%
# Send a message for QGC to read out loud
#  Severity from https://mavlink.io/en/messages/common.html#MAV_SEVERITY
master.mav.statustext_send(mavutil.mavlink.MAV_SEVERITY_NOTICE,
                           "QGC will read this".encode())

# %% [markdown]
# ### Arm and disarm

# %%
master.mav.command_long_send(
    master.target_system,
    master.target_component,
    mavutil.mavlink.MAV_CMD_COMPONENT_ARM_DISARM,
    0,
    1, 0, 0, 0, 0, 0, 0)

# wait until arming confirmed (can manually check with master.motors_armed())
print("Waiting for the vehicle to arm")
master.motors_armed_wait()
print('Armed!')
# Out:
# Waiting for the vehicle to arm
# Armed!

# %%
# OR
master.arducopter_arm()

# %%
master.mav.command_long_send(
    master.target_system,
    master.target_component,
    mavutil.mavlink.MAV_CMD_COMPONENT_ARM_DISARM,
    0,
    0, 0, 0, 0, 0, 0, 0)

# wait until disarming confirmed
print("Waiting for the vehicle to disarm")
master.motors_disarmed_wait()
print('Disarmed!')
# Out:
# Waiting for the vehicle to disarm
# Disarmed!

# %%
# OR
master.arducopter_disarm()

# %% [markdown]
# ### Change Flight Mode

# %%
# Choose a mode
mode = 'STABILIZE'
# mode = 'GUIDED'

# Check if mode is available
if mode not in master.mode_mapping():
    print('Unknown mode : {}'.format(mode))
    print('Try:', list(master.mode_mapping().keys()))
    sys.exit(1)

# Get mode ID
mode_id = master.mode_mapping()[mode]

# %%
# Set new mode
# master.mav.command_long_send(
#    master.target_system, master.target_component,
#    mavutil.mavlink.MAV_CMD_DO_SET_MODE, 0,
#    0, mode_id, 0, 0, 0, 0, 0)
# OR
master.set_mode(mode_id)
# OR
# master.mav.set_mode_send(
#     master.target_system,
#     mavutil.mavlink.MAV_MODE_FLAG_CUSTOM_MODE_ENABLED,
#     mode_id)

while True:
    # Wait for ACK command
    # Would be good to add mechanism to avoid endlessly blocking
    # if the autopilot sends a NACK or never receives the message
    ack_msg = master.recv_match(type='COMMAND_ACK', blocking=True)
    ack_msg = ack_msg.to_dict()

    # Continue waiting if the acknowledged command is not `set_mode`
    if ack_msg['command'] != mavutil.mavlink.MAV_CMD_DO_SET_MODE:
        continue

    # Print the ACK result !
    print(mavutil.mavlink.enums['MAV_RESULT'][ack_msg['result']].description)
    break
# Out:
# Command is valid (is supported and has valid parameters), and was executed.

# %% [markdown]
# ### Use RC

# %%
# Create a function to send RC values
# More information about Joystick channels
# here: https://www.ardusub.com/operators-manual/rc-input-and-output.html#rc-inputs

def set_rc_channel_pwm(channel_id, pwm=1500):
    """ Set RC channel pwm value
    Args:
        channel_id (TYPE): Channel ID
        pwm (int, optional): Channel pwm value 1100-1900
    """
    if channel_id < 1 or channel_id > 18:
        print("Channel does not exist.")
        return

    # Mavlink 2 supports up to 18 channels:
    # https://mavlink.io/en/messages/common.html#RC_CHANNELS_OVERRIDE
    rc_channel_values = [65535 for _ in range(18)]
    rc_channel_values[channel_id - 1] = pwm
    master.mav.rc_channels_override_send(
        master.target_system,                # target_system
        master.target_component,             # target_component
        *rc_channel_values)                  # RC channel list, in microseconds.

# %%
# Manual mode
mode = 'STABILIZE'
if mode not in master.mode_mapping():
    print('Unknown mode : {}'.format(mode))
    print('Try:', list(master.mode_mapping().keys()))
    sys.exit(1)
mode_id = master.mode_mapping()[mode]

# %%
# 1500 : joystick au centre (1100 et 1900)
while True:
    set_rc_channel_pwm(1, 1600)  # ROLL
    set_rc_channel_pwm(2, 1400)  # PITCH
    set_rc_channel_pwm(3, 1475)  # THROTTLE Monte doucement : 1475
    set_rc_channel_pwm(4, 1400)  # YAW
    time.sleep(0.1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[81], line 7
#       5 set_rc_channel_pwm(3, 1475)  # THROTTLE Monte doucement : 1475
#       6 set_rc_channel_pwm(4, 1400)  # YAW
# ----> 7 time.sleep(0.1)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Controle manuel (imitaion d'une télécommande)

# %%
# Manual mode
mode = 'STABILIZE'
if mode not in master.mode_mapping():
    print('Unknown mode : {}'.format(mode))
    print('Try:', list(master.mode_mapping().keys()))
    sys.exit(1)
mode_id = master.mode_mapping()[mode]

# %%
# Send a positive x value, negative y, negative z,
# positive rotation and no button.
# https://mavlink.io/en/messages/common.html#MANUAL_CONTROL
# Warning: Because of some legacy workaround, z will work between [0-1000]
# where 0 is full reverse, 500 is no output and 1000 is full throttle.
# x,y and r will be between [-1000 and 1000].

# To active button 0 (first button), 3 (fourth button) and 7 (eighth button)
# It's possible to check and configure this buttons in the Joystick menu of QGC
buttons = 1 + 1 << 3 + 1 << 7

master.set_mode(mode)
while True:
    master.mav.manual_control_send(
        master.target_system,
        100, # PTICH
        100, # ROLL
        475, # THROTLLE (475 monte doucement)
        100, # YAW 
        buttons)
    time.sleep(0.1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[85], line 21
#      13 while True:
#      14     master.mav.manual_control_send(
#      15         master.target_system,
#      16         100, # PTICH
#    (...)
#      19         100, # YAW
#      20         buttons)
# ---> 21     time.sleep(0.1)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Read all parameters

# %%
master.mav.param_request_list_send(
    master.target_system, master.target_component
)
while True:
    time.sleep(0.01)
    try:
        message = master.recv_match(type='PARAM_VALUE', blocking=True).to_dict()
        print('name: %s\tvalue: %d' % (message['param_id'],
                                       message['param_value']))
    except Exception as error:
        print(error)
        sys.exit(0)
# Out:
# name: LAND_SPEED	value: 5
# name: LAND_SPEED	value: 5
# name: LAND_SPEED	value: 5
# name: LAND_SPEED	value: 5
# name: LAND_SPEED	value: 5
# name: LAND_SPEED	value: 5
# name: LAND_SPEED	value: 5
# name: LAND_SPEED	value: 5
# name: STAT_RUNTIME	value: 1487
# name: LAND_SPEED	value: 5
# name: STAT_RUNTIME	value: 1518
# name: STAT_RUNTIME	value: 1549
# name: STAT_RUNTIME	value: 1580
# name: STAT_RUNTIME	value: 1611
# name: STAT_RUNTIME	value: 1642
# name: STAT_RUNTIME	value: 1673
# name: STAT_RUNTIME	value: 1704
# name: STAT_RUNTIME	value: 1735
# name: LAND_SPEED	value: 5
# name: STAT_RUNTIME	value: 1766
# name: LAND_SPEED	value: 5
# name: LAND_SPEED	value: 5
# name: LAND_SPEED	value: 5
# name: LAND_SPEED	value: 5
# name: LAND_SPEED	value: 5
# name: FORMAT_VERSION	value: 120
# name: SYSID_THISMAV	value: 1
# name: SYSID_MYGCS	value: 255
# name: PILOT_THR_FILT	value: 0
# name: PILOT_TKOFF_ALT	value: 0
# name: PILOT_THR_BHV	value: 0
# name: TELEM_DELAY	value: 0
# name: GCS_PID_MASK	value: 0
# name: RTL_ALT	value: 1500
# name: RTL_CONE_SLOPE	value: 3
# name: RTL_SPEED	value: 0
# name: RTL_ALT_FINAL	value: 0
# name: RTL_CLIMB_MIN	value: 0
# name: RTL_LOIT_TIME	value: 5000
# name: RTL_ALT_TYPE	value: 0
# name: FS_GCS_ENABLE	value: 0
# name: GPS_HDOP_GOOD	value: 140
# name: SUPER_SIMPLE	value: 0
# name: WP_YAW_BEHAVIOR	value: 2
# name: LAND_SPEED	value: 5
# name: LAND_SPEED_HIGH	value: 0
# name: PILOT_SPEED_UP	value: 250
# name: PILOT_ACCEL_Z	value: 250
# name: FS_THR_ENABLE	value: 1
# name: FS_THR_VALUE	value: 975
# name: THR_DZ	value: 100
# name: FLTMODE1	value: 7
# name: FLTMODE2	value: 9
# name: FLTMODE3	value: 6
# name: FLTMODE4	value: 3
# name: FLTMODE5	value: 5
# name: FLTMODE6	value: 0
# name: FLTMODE_CH	value: 5
# name: INITIAL_MODE	value: 0
# name: SIMPLE	value: 0
# name: LOG_BITMASK	value: 176126
# name: ESC_CALIBRATION	value: 0
# name: TUNE	value: 0
# name: FRAME_TYPE	value: 0
# name: ARMING_ACCTHRESH	value: 0
# name: ARMING_RUDDER	value: 2
# name: ARMING_MIS_ITEMS	value: 0
# name: ARMING_CHECK	value: 1
# name: ARMING_OPTIONS	value: 0
# name: ARMING_MAGTHRESH	value: 100
# name: DISARM_DELAY	value: 10
# name: ANGLE_MAX	value: 3000
# name: PHLD_BRAKE_RATE	value: 8
# name: PHLD_BRAKE_ANGLE	value: 3000
# name: LAND_REPOSITION	value: 1
# name: FS_EKF_ACTION	value: 1
# name: FS_EKF_THRESH	value: 0
# name: FS_CRASH_CHECK	value: 1
# name: RC_SPEED	value: 490
# name: ACRO_BAL_ROLL	value: 1
# name: ACRO_BAL_PITCH	value: 1
# name: ACRO_TRAINER	value: 2
# name: CAM_MAX_ROLL	value: 0
# name: CAM_AUTO_ONLY	value: 0
# name: CAM1_TYPE	value: 0
# name: CAM2_TYPE	value: 0
# name: RELAY1_FUNCTION	value: 1
# name: RELAY1_PIN	value: 13
# name: RELAY1_DEFAULT	value: 0
# name: RELAY1_INVERTED	value: 0
# name: RELAY2_FUNCTION	value: 0
# name: RELAY3_FUNCTION	value: 0
# name: RELAY4_FUNCTION	value: 0
# name: RELAY5_FUNCTION	value: 0
# name: RELAY6_FUNCTION	value: 0
# name: CHUTE_ENABLED	value: 0
# name: LGR_ENABLE	value: 0
# name: COMPASS_OFS_X	value: 5
# name: COMPASS_OFS_Y	value: 13
# name: COMPASS_OFS_Z	value: -18
# name: COMPASS_DEC	value: 0
# name: COMPASS_LEARN	value: 0
# name: COMPASS_USE	value: 1
# name: COMPASS_AUTODEC	value: 1
# name: COMPASS_MOTCT	value: 0
# name: COMPASS_MOT_X	value: 0
# name: COMPASS_MOT_Y	value: 0
# name: COMPASS_MOT_Z	value: 0
# name: COMPASS_ORIENT	value: 0
# name: COMPASS_EXTERNAL	value: 1
# name: COMPASS_OFS2_X	value: 5
# name: COMPASS_OFS2_Y	value: 13
# name: COMPASS_OFS2_Z	value: -18
# name: COMPASS_MOT2_X	value: 0
# name: COMPASS_MOT2_Y	value: 0
# name: COMPASS_MOT2_Z	value: 0
# name: COMPASS_OFS3_X	value: 5
# name: COMPASS_OFS3_Y	value: 13
# name: COMPASS_OFS3_Z	value: -18
# name: COMPASS_MOT3_X	value: 0
# name: COMPASS_MOT3_Y	value: 0
# name: COMPASS_MOT3_Z	value: 0
# name: COMPASS_DEV_ID	value: 97539
# name: COMPASS_DEV_ID2	value: 131874
# name: COMPASS_DEV_ID3	value: 263178
# name: COMPASS_USE2	value: 1
# name: COMPASS_ORIENT2	value: 0
# name: COMPASS_EXTERN2	value: 0
# name: COMPASS_USE3	value: 1
# name: COMPASS_ORIENT3	value: 0
# name: COMPASS_EXTERN3	value: 0
# name: COMPASS_DIA_X	value: 1
# name: COMPASS_DIA_Y	value: 1
# name: COMPASS_DIA_Z	value: 1
# name: COMPASS_ODI_X	value: 0
# name: COMPASS_ODI_Y	value: 0
# name: COMPASS_ODI_Z	value: 0
# name: COMPASS_DIA2_X	value: 1
# name: COMPASS_DIA2_Y	value: 1
# name: COMPASS_DIA2_Z	value: 1
# name: COMPASS_ODI2_X	value: 0
# name: COMPASS_ODI2_Y	value: 0
# name: COMPASS_ODI2_Z	value: 0
# name: COMPASS_DIA3_X	value: 1
# name: COMPASS_DIA3_Y	value: 1
# name: COMPASS_DIA3_Z	value: 1
# name: COMPASS_ODI3_X	value: 0
# name: COMPASS_ODI3_Y	value: 0
# name: COMPASS_ODI3_Z	value: 0
# name: COMPASS_CAL_FIT	value: 16
# name: COMPASS_OFFS_MAX	value: 1800
# name: COMPASS_PMOT_EN	value: 0
# name: COMPASS_DISBLMSK	value: 0
# name: COMPASS_FLTR_RNG	value: 0
# name: COMPASS_AUTO_ROT	value: 2
# name: COMPASS_PRIO1_ID	value: 97539
# name: COMPASS_PRIO2_ID	value: 131874
# name: COMPASS_PRIO3_ID	value: 263178
# name: COMPASS_ENABLE	value: 1
# name: COMPASS_SCALE	value: 1
# name: COMPASS_SCALE2	value: 1
# name: COMPASS_SCALE3	value: 1
# name: COMPASS_OPTIONS	value: 0
# name: COMPASS_DEV_ID4	value: 97283
# name: COMPASS_DEV_ID5	value: 97795
# name: COMPASS_DEV_ID6	value: 98051
# name: COMPASS_DEV_ID7	value: 0
# name: COMPASS_DEV_ID8	value: 0
# name: INS_GYROFFS_X	value: 0
# name: INS_GYROFFS_Y	value: 0
# name: INS_GYROFFS_Z	value: 0
# name: INS_GYR2OFFS_X	value: 0
# name: INS_GYR2OFFS_Y	value: 0
# name: INS_GYR2OFFS_Z	value: 0
# name: INS_GYR3OFFS_X	value: 0
# name: INS_GYR3OFFS_Y	value: 0
# name: INS_GYR3OFFS_Z	value: 0
# name: INS_ACCSCAL_X	value: 1
# name: INS_ACCSCAL_Y	value: 1
# name: INS_ACCSCAL_Z	value: 1
# name: INS_ACCOFFS_X	value: 0
# name: INS_ACCOFFS_Y	value: 0
# name: INS_ACCOFFS_Z	value: 0
# name: INS_ACC2SCAL_X	value: 1
# name: INS_ACC2SCAL_Y	value: 1
# name: INS_ACC2SCAL_Z	value: 1
# name: INS_ACC2OFFS_X	value: 0
# name: INS_ACC2OFFS_Y	value: 0
# name: INS_ACC2OFFS_Z	value: 0
# name: INS_ACC3SCAL_X	value: 1
# name: INS_ACC3SCAL_Y	value: 1
# name: INS_ACC3SCAL_Z	value: 1
# name: INS_ACC3OFFS_X	value: 0
# name: INS_ACC3OFFS_Y	value: 0
# name: INS_ACC3OFFS_Z	value: 0
# name: INS_GYRO_FILTER	value: 20
# name: INS_ACCEL_FILTER	value: 20
# name: INS_USE	value: 1
# name: INS_USE2	value: 1
# name: INS_USE3	value: 1
# name: INS_STILL_THRESH	value: 2
# name: INS_GYR_CAL	value: 1
# name: INS_TRIM_OPTION	value: 1
# name: INS_ACC_BODYFIX	value: 2
# name: INS_POS1_X	value: 0
# name: INS_POS1_Y	value: 0
# name: INS_POS1_Z	value: 0
# name: INS_POS2_X	value: 0
# name: INS_POS2_Y	value: 0
# name: INS_POS2_Z	value: 0
# name: INS_POS3_X	value: 0
# name: INS_POS3_Y	value: 0
# name: INS_POS3_Z	value: 0
# name: INS_GYR_ID	value: 2752772
# name: INS_GYR2_ID	value: 2752780
# name: INS_GYR3_ID	value: 0
# name: INS_ACC_ID	value: 2753028
# name: INS_ACC2_ID	value: 2753036
# name: INS_ACC3_ID	value: 0
# name: INS_FAST_SAMPLE	value: 1
# name: INS_LOG_BAT_CNT	value: 1024
# name: INS_LOG_BAT_MASK	value: 0
# name: INS_LOG_BAT_OPT	value: 0
# name: INS_LOG_BAT_LGIN	value: 20
# name: INS_LOG_BAT_LGCT	value: 32
# name: INS_ENABLE_MASK	value: 127
# name: INS_HNTCH_ENABLE	value: 0
# name: INS_HNTC2_ENABLE	value: 0
# name: INS_GYRO_RATE	value: 0
# name: INS_TCAL1_ENABLE	value: 0
# name: INS_TCAL2_ENABLE	value: 0
# name: INS_TCAL3_ENABLE	value: 0
# name: INS_ACC1_CALTEMP	value: -300
# name: INS_GYR1_CALTEMP	value: 25
# name: INS_ACC2_CALTEMP	value: -300
# name: INS_GYR2_CALTEMP	value: 25
# name: INS_ACC3_CALTEMP	value: -300
# name: INS_GYR3_CALTEMP	value: -300
# name: INS_TCAL_OPTIONS	value: 0
# name: INS_RAW_LOG_OPT	value: 0
# name: WPNAV_SPEED	value: 1000
# name: WPNAV_RADIUS	value: 200
# name: WPNAV_SPEED_UP	value: 250
# name: WPNAV_SPEED_DN	value: 150
# name: WPNAV_ACCEL	value: 250
# name: WPNAV_ACCEL_Z	value: 100
# name: WPNAV_RFND_USE	value: 1
# name: WPNAV_JERK	value: 1
# name: WPNAV_TER_MARGIN	value: 10
# name: WPNAV_ACCEL_C	value: 0
# name: LOIT_ANG_MAX	value: 0
# name: LOIT_SPEED	value: 1250
# name: LOIT_ACC_MAX	value: 500
# name: LOIT_BRK_ACCEL	value: 250
# name: LOIT_BRK_JERK	value: 500
# name: LOIT_BRK_DELAY	value: 1
# name: CIRCLE_RADIUS	value: 1000
# name: CIRCLE_RATE	value: 20
# name: CIRCLE_OPTIONS	value: 1
# name: ATC_SLEW_YAW	value: 6000
# name: ATC_ACCEL_Y_MAX	value: 27000
# name: ATC_RATE_FF_ENAB	value: 1
# name: ATC_ACCEL_R_MAX	value: 110000
# name: ATC_ACCEL_P_MAX	value: 110000
# name: ATC_ANGLE_BOOST	value: 1
# name: ATC_ANG_RLL_P	value: 4
# name: ATC_ANG_PIT_P	value: 4
# name: ATC_ANG_YAW_P	value: 4
# name: ATC_ANG_LIM_TC	value: 1
# name: ATC_RATE_R_MAX	value: 0
# name: ATC_RATE_P_MAX	value: 0
# name: ATC_RATE_Y_MAX	value: 0
# name: ATC_INPUT_TC	value: 0
# name: ATC_LAND_R_MULT	value: 1
# name: ATC_LAND_P_MULT	value: 1
# name: ATC_LAND_Y_MULT	value: 1
# name: ATC_RAT_RLL_P	value: 0
# name: ATC_RAT_RLL_I	value: 0
# name: ATC_RAT_RLL_D	value: 0
# name: ATC_RAT_RLL_FF	value: 0
# name: ATC_RAT_RLL_IMAX	value: 0
# name: ATC_RAT_RLL_FLTT	value: 20
# name: ATC_RAT_RLL_FLTE	value: 0
# name: ATC_RAT_RLL_FLTD	value: 20
# name: ATC_RAT_RLL_SMAX	value: 0
# name: ATC_RAT_RLL_PDMX	value: 0
# name: ATC_RAT_RLL_D_FF	value: 0
# name: ATC_RAT_RLL_NTF	value: 0
# name: ATC_RAT_RLL_NEF	value: 0
# name: ATC_RAT_PIT_P	value: 0
# name: ATC_RAT_PIT_I	value: 0
# name: ATC_RAT_PIT_D	value: 0
# name: ATC_RAT_PIT_FF	value: 0
# name: ATC_RAT_PIT_IMAX	value: 0
# name: ATC_RAT_PIT_FLTT	value: 20
# name: ATC_RAT_PIT_FLTE	value: 0
# name: ATC_RAT_PIT_FLTD	value: 20
# name: ATC_RAT_PIT_SMAX	value: 0
# name: ATC_RAT_PIT_PDMX	value: 0
# name: ATC_RAT_PIT_D_FF	value: 0
# name: ATC_RAT_PIT_NTF	value: 0
# name: ATC_RAT_PIT_NEF	value: 0
# name: ATC_RAT_YAW_P	value: 0
# name: ATC_RAT_YAW_I	value: 0
# name: ATC_RAT_YAW_D	value: 0
# name: ATC_RAT_YAW_FF	value: 0
# name: ATC_RAT_YAW_IMAX	value: 0
# name: ATC_RAT_YAW_FLTT	value: 20
# name: ATC_RAT_YAW_FLTE	value: 2
# name: ATC_RAT_YAW_FLTD	value: 20
# name: ATC_RAT_YAW_SMAX	value: 0
# name: ATC_RAT_YAW_PDMX	value: 0
# name: ATC_RAT_YAW_D_FF	value: 0
# name: ATC_RAT_YAW_NTF	value: 0
# name: ATC_RAT_YAW_NEF	value: 0
# name: ATC_THR_MIX_MIN	value: 0
# name: ATC_THR_MIX_MAX	value: 0
# name: ATC_THR_MIX_MAN	value: 0
# name: ATC_THR_G_BOOST	value: 0
# name: PSC_POSZ_P	value: 1
# name: PSC_VELZ_P	value: 5
# name: PSC_VELZ_I	value: 0
# name: PSC_VELZ_IMAX	value: 1000
# name: PSC_VELZ_FLTE	value: 5
# name: PSC_VELZ_D	value: 0
# name: PSC_VELZ_FLTD	value: 5
# name: PSC_VELZ_FF	value: 0
# name: PSC_ACCZ_P	value: 0
# name: PSC_ACCZ_I	value: 1
# name: PSC_ACCZ_D	value: 0
# name: PSC_ACCZ_FF	value: 0
# name: PSC_ACCZ_IMAX	value: 800
# name: PSC_ACCZ_FLTT	value: 0
# name: PSC_ACCZ_FLTE	value: 20
# name: PSC_ACCZ_FLTD	value: 0
# name: PSC_ACCZ_SMAX	value: 0
# name: PSC_ACCZ_PDMX	value: 0
# name: PSC_ACCZ_D_FF	value: 0
# name: PSC_ACCZ_NTF	value: 0
# name: PSC_ACCZ_NEF	value: 0
# name: PSC_POSXY_P	value: 1
# name: PSC_VELXY_P	value: 2
# name: PSC_VELXY_I	value: 1
# name: PSC_VELXY_IMAX	value: 1000
# name: PSC_VELXY_FLTE	value: 5
# name: PSC_VELXY_D	value: 0
# name: PSC_VELXY_FLTD	value: 5
# name: PSC_VELXY_FF	value: 0
# name: PSC_ANGLE_MAX	value: 0
# name: PSC_JERK_XY	value: 5
# name: PSC_JERK_Z	value: 5
# name: SR0_RAW_SENS	value: 4
# name: SR0_EXT_STAT	value: 4
# name: SR0_RC_CHAN	value: 4
# name: SR0_RAW_CTRL	value: 4
# name: SR0_POSITION	value: 4
# name: SR0_EXTRA1	value: 4
# name: SR0_EXTRA2	value: 4
# name: SR0_EXTRA3	value: 4
# name: SR0_PARAMS	value: 0
# name: SR0_ADSB	value: 4
# name: SR1_RAW_SENS	value: 0
# name: SR1_EXT_STAT	value: 0
# name: SR1_RC_CHAN	value: 0
# name: SR1_RAW_CTRL	value: 0
# name: SR1_POSITION	value: 0
# name: SR1_EXTRA1	value: 0
# name: SR1_EXTRA2	value: 0
# name: SR1_EXTRA3	value: 0
# name: SR1_PARAMS	value: 0
# name: SR1_ADSB	value: 0
# name: SR2_RAW_SENS	value: 0
# name: SR2_EXT_STAT	value: 0
# name: SR2_RC_CHAN	value: 0
# name: SR2_RAW_CTRL	value: 0
# name: SR2_POSITION	value: 0
# name: SR2_EXTRA1	value: 0
# name: SR2_EXTRA2	value: 0
# name: SR2_EXTRA3	value: 0
# name: SR2_PARAMS	value: 0
# name: SR2_ADSB	value: 0
# name: SR3_RAW_SENS	value: 0
# name: SR3_EXT_STAT	value: 0
# name: SR3_RC_CHAN	value: 0
# name: SR3_RAW_CTRL	value: 0
# name: SR3_POSITION	value: 0
# name: SR3_EXTRA1	value: 0
# name: SR3_EXTRA2	value: 0
# name: SR3_EXTRA3	value: 0
# name: SR3_PARAMS	value: 0
# name: SR3_ADSB	value: 0
# name: SR4_RAW_SENS	value: 0
# name: SR4_EXT_STAT	value: 0
# name: SR4_RC_CHAN	value: 0
# name: SR4_RAW_CTRL	value: 0
# name: SR4_POSITION	value: 0
# name: SR4_EXTRA1	value: 0
# name: SR4_EXTRA2	value: 0
# name: SR4_EXTRA3	value: 0
# name: SR4_PARAMS	value: 0
# name: SR4_ADSB	value: 0
# name: SR5_RAW_SENS	value: 0
# name: SR5_EXT_STAT	value: 0
# name: SR5_RC_CHAN	value: 0
# name: SR5_RAW_CTRL	value: 0
# name: SR5_POSITION	value: 0
# name: SR5_EXTRA1	value: 0
# name: SR5_EXTRA2	value: 0
# name: SR5_EXTRA3	value: 0
# name: SR5_PARAMS	value: 0
# name: SR5_ADSB	value: 0
# name: SR6_RAW_SENS	value: 0
# name: SR6_EXT_STAT	value: 0
# name: SR6_RC_CHAN	value: 0
# name: SR6_RAW_CTRL	value: 0
# name: SR6_POSITION	value: 0
# name: SR6_EXTRA1	value: 0
# name: SR6_EXTRA2	value: 0
# name: SR6_EXTRA3	value: 0
# name: SR6_PARAMS	value: 0
# name: SR6_ADSB	value: 0
# name: AHRS_GPS_GAIN	value: 1
# name: AHRS_GPS_USE	value: 1
# name: AHRS_YAW_P	value: 0
# name: AHRS_RP_P	value: 0
# name: AHRS_WIND_MAX	value: 0
# name: AHRS_TRIM_X	value: 0
# name: AHRS_TRIM_Y	value: 0
# name: AHRS_TRIM_Z	value: 0
# name: AHRS_ORIENTATION	value: 0
# name: AHRS_COMP_BETA	value: 0
# name: AHRS_GPS_MINSATS	value: 6
# name: AHRS_EKF_TYPE	value: 3
# name: AHRS_OPTIONS	value: 0
# name: MNT1_TYPE	value: 0
# name: MNT2_TYPE	value: 0
# name: BATT_MONITOR	value: 4
# name: BATT_CAPACITY	value: 3300
# name: BATT_SERIAL_NUM	value: -1
# name: BATT_LOW_TIMER	value: 10
# name: BATT_FS_VOLTSRC	value: 0
# name: BATT_LOW_VOLT	value: 5
# name: BATT_LOW_MAH	value: 0
# name: BATT_CRT_VOLT	value: 0
# name: BATT_CRT_MAH	value: 0
# name: BATT_FS_LOW_ACT	value: 0
# name: BATT_FS_CRT_ACT	value: 0
# name: BATT_ARM_VOLT	value: 0
# name: BATT_ARM_MAH	value: 0
# name: BATT_OPTIONS	value: 0
# name: BATT_VOLT_PIN	value: 13
# name: BATT_CURR_PIN	value: 12
# name: BATT_VOLT_MULT	value: 10
# name: BATT_AMP_PERVLT	value: 17
# name: BATT_AMP_OFFSET	value: 0
# name: BATT_VLT_OFFSET	value: 0
# name: BATT2_MONITOR	value: 0
# name: BATT3_MONITOR	value: 0
# name: BATT4_MONITOR	value: 0
# name: BATT5_MONITOR	value: 0
# name: BATT6_MONITOR	value: 0
# name: BATT7_MONITOR	value: 0
# name: BATT8_MONITOR	value: 0
# name: BATT9_MONITOR	value: 0
# name: BRD_SAFETY_DEFLT	value: 0
# name: BRD_SERIAL_NUM	value: 0
# name: BRD_SAFETY_MASK	value: 16368
# name: BRD_SAFETYOPTION	value: 3
# name: BRD_RTC_TYPES	value: 1
# name: BRD_RTC_TZ_MIN	value: 0
# name: BRD_VBUS_MIN	value: 4
# name: BRD_VSERVO_MIN	value: 0
# name: BRD_OPTIONS	value: 0
# name: BRD_BOOT_DELAY	value: 0
# name: BRD_SD_MISSION	value: 0
# name: BRD_SD_FENCE	value: 0
# name: CAN_P1_DRIVER	value: 0
# name: CAN_P2_DRIVER	value: 0
# name: CAN_D1_PROTOCOL	value: 1
# name: CAN_D1_PROTOCOL2	value: 0
# name: CAN_D2_PROTOCOL	value: 1
# name: CAN_D2_PROTOCOL2	value: 0
# name: CAN_LOGLEVEL	value: 0
# name: SPRAY_ENABLE	value: 0
# name: SIM_DRIFT_SPEED	value: 0
# name: SIM_DRIFT_TIME	value: 5
# name: SIM_ENGINE_MUL	value: 0
# name: SIM_WIND_SPD	value: 0
# name: SIM_WIND_DIR	value: 180
# name: SIM_WIND_TURB	value: 0
# name: SIM_WIND_TC	value: 5
# name: SIM_SERVO_SPEED	value: 0
# name: SIM_SERVO_DELAY	value: 0
# name: SIM_SERVO_FILTER	value: 0
# name: SIM_SONAR_ROT	value: 25
# name: SIM_BATT_VOLTAGE	value: 12
# name: SIM_BATT_CAP_AH	value: 0
# name: SIM_SONAR_GLITCH	value: 0
# name: SIM_SONAR_RND	value: 0
# name: SIM_RC_FAIL	value: 0
# name: SIM_FLOAT_EXCEPT	value: 1
# name: SIM_CAN_SRV_MSK	value: 0
# name: SIM_CAN_TYPE1	value: 1
# name: SIM_CAN_TYPE2	value: 1
# name: SIM_SONAR_SCALE	value: 12
# name: SIM_FLOW_ENABLE	value: 0
# name: SIM_TERRAIN	value: 1
# name: SIM_FLOW_RATE	value: 10
# name: SIM_FLOW_DELAY	value: 0
# name: SIM_ADSB_COUNT	value: -1
# name: SIM_ADSB_RADIUS	value: 10000
# name: SIM_ADSB_ALT	value: 1000
# name: SIM_PIN_MASK	value: 0
# name: SIM_ADSB_TX	value: 0
# name: SIM_SPEEDUP	value: 1
# name: SIM_IMU_POS_X	value: 0
# name: SIM_IMU_POS_Y	value: 0
# name: SIM_IMU_POS_Z	value: 0
# name: SIM_IMUT_START	value: 25
# name: SIM_IMUT_END	value: 45
# name: SIM_IMUT_TCONST	value: 300
# name: SIM_IMUT_FIXED	value: 0
# name: SIM_ACC1_BIAS_X	value: 0
# name: SIM_ACC1_BIAS_Y	value: 0
# name: SIM_ACC1_BIAS_Z	value: 0
# name: SIM_ACC2_BIAS_X	value: 0
# name: SIM_ACC2_BIAS_Y	value: 0
# name: SIM_ACC2_BIAS_Z	value: 0
# name: SIM_ACC3_BIAS_X	value: 0
# name: SIM_ACC3_BIAS_Y	value: 0
# name: SIM_ACC3_BIAS_Z	value: 0
# name: SIM_GYR1_RND	value: 0
# name: SIM_GYR2_RND	value: 0
# name: SIM_GYR3_RND	value: 0
# name: SIM_ACC1_RND	value: 0
# name: SIM_ACC2_RND	value: 0
# name: SIM_ACC3_RND	value: 0
# name: SIM_GYR1_SCALE_X	value: 0
# name: SIM_GYR1_SCALE_Y	value: 0
# name: SIM_GYR1_SCALE_Z	value: 0
# name: SIM_GYR2_SCALE_X	value: 0
# name: SIM_GYR2_SCALE_Y	value: 0
# name: SIM_GYR2_SCALE_Z	value: 0
# name: SIM_GYR3_SCALE_X	value: 0
# name: SIM_GYR3_SCALE_Y	value: 0
# name: SIM_GYR3_SCALE_Z	value: 0
# name: SIM_ACCEL1_FAIL	value: 0
# name: SIM_ACCEL2_FAIL	value: 0
# name: SIM_ACCEL3_FAIL	value: 0
# name: SIM_GYR_FAIL_MSK	value: 0
# name: SIM_ACC_FAIL_MSK	value: 0
# name: SIM_ACC1_SCAL_X	value: 0
# name: SIM_ACC1_SCAL_Y	value: 0
# name: SIM_ACC1_SCAL_Z	value: 0
# name: SIM_ACC2_SCAL_X	value: 0
# name: SIM_ACC2_SCAL_Y	value: 0
# name: SIM_ACC2_SCAL_Z	value: 0
# name: SIM_ACC3_SCAL_X	value: 0
# name: SIM_ACC3_SCAL_Y	value: 0
# name: SIM_ACC3_SCAL_Z	value: 0
# name: SIM_ACC_TRIM_X	value: 0
# name: SIM_ACC_TRIM_Y	value: 0
# name: SIM_ACC_TRIM_Z	value: 0
# name: SIM_JSON_MASTER	value: 0
# name: SIM_OH_MASK	value: 0
# name: SIM_GYR_FILE_RW	value: 0
# name: SIM_ACC_FILE_RW	value: 0
# name: SIM_GYR1_BIAS_X	value: 0
# name: SIM_GYR1_BIAS_Y	value: 0
# name: SIM_GYR1_BIAS_Z	value: 0
# name: SIM_GYR2_BIAS_X	value: 0
# name: SIM_GYR2_BIAS_Y	value: 0
# name: SIM_GYR2_BIAS_Z	value: 0
# name: SIM_GYR3_BIAS_X	value: 0
# name: SIM_GYR3_BIAS_Y	value: 0
# name: SIM_GYR3_BIAS_Z	value: 0
# name: SIM_OH_RELAY_MSK	value: -1
# name: SIM_CLAMP_CH	value: 0
# name: SIM_IMUT1_ENABLE	value: 0
# name: SIM_IMUT2_ENABLE	value: 0
# name: SIM_IMUT3_ENABLE	value: 0
# name: SIM_SONAR_POS_X	value: 0
# name: SIM_SONAR_POS_Y	value: 0
# name: SIM_SONAR_POS_Z	value: 0
# name: SIM_FLOW_POS_X	value: 0
# name: SIM_FLOW_POS_Y	value: 0
# name: SIM_FLOW_POS_Z	value: 0
# name: SIM_ENGINE_FAIL	value: 0
# name: SIM_SHIP_ENABLE	value: 0
# name: SIM_SHIP_SPEED	value: 3
# name: SIM_SHIP_PSIZE	value: 1000
# name: SIM_SHIP_SYSID	value: 17
# name: SIM_SHIP_DSIZE	value: 10
# name: SIM_SHIP_OFS_X	value: 0
# name: SIM_SHIP_OFS_Y	value: 0
# name: SIM_SHIP_OFS_Z	value: 0
# name: SIM_SLUP_ENABLE	value: 0
# name: SIM_TETH_ENABLE	value: 0
# name: SIM_MAG_RND	value: 0
# name: SIM_MAG_MOT_X	value: 0
# name: SIM_MAG_MOT_Y	value: 0
# name: SIM_MAG_MOT_Z	value: 0
# name: SIM_MAG_DELAY	value: 0
# name: SIM_MAG1_OFS_X	value: 5
# name: SIM_MAG1_OFS_Y	value: 13
# name: SIM_MAG1_OFS_Z	value: -18
# name: SIM_MAG_ALY_X	value: 0
# name: SIM_MAG_ALY_Y	value: 0
# name: SIM_MAG_ALY_Z	value: 0
# name: SIM_MAG_ALY_HGT	value: 1
# name: SIM_MAG1_DIA_X	value: 0
# name: SIM_MAG1_DIA_Y	value: 0
# name: SIM_MAG1_DIA_Z	value: 0
# name: SIM_MAG1_ODI_X	value: 0
# name: SIM_MAG1_ODI_Y	value: 0
# name: SIM_MAG1_ODI_Z	value: 0
# name: SIM_MAG1_ORIENT	value: 0
# name: SIM_MAG1_SCALING	value: 1
# name: SIM_MAG1_DEVID	value: 97539
# name: SIM_MAG2_DEVID	value: 131874
# name: SIM_MAG3_DEVID	value: 263178
# name: SIM_MAG4_DEVID	value: 97283
# name: SIM_MAG5_DEVID	value: 97795
# name: SIM_MAG6_DEVID	value: 98051
# name: SIM_MAG7_DEVID	value: 0
# name: SIM_MAG8_DEVID	value: 0
# name: SIM_MAG1_FAIL	value: 0
# name: SIM_MAG2_OFS_X	value: 5
# name: SIM_MAG2_OFS_Y	value: 13
# name: SIM_MAG2_OFS_Z	value: -18
# name: SIM_MAG2_DIA_X	value: 0
# name: SIM_MAG2_DIA_Y	value: 0
# name: SIM_MAG2_DIA_Z	value: 0
# name: SIM_MAG2_ODI_X	value: 0
# name: SIM_MAG2_ODI_Y	value: 0
# name: SIM_MAG2_ODI_Z	value: 0
# name: SIM_MAG2_ORIENT	value: 0
# name: SIM_MAG2_FAIL	value: 0
# name: SIM_MAG2_SCALING	value: 1
# name: SIM_MAG3_OFS_X	value: 5
# name: SIM_MAG3_OFS_Y	value: 13
# name: SIM_MAG3_OFS_Z	value: -18
# name: SIM_MAG3_DIA_X	value: 0
# name: SIM_MAG3_DIA_Y	value: 0
# name: SIM_MAG3_DIA_Z	value: 0
# name: SIM_MAG3_ODI_X	value: 0
# name: SIM_MAG3_ODI_Y	value: 0
# name: SIM_MAG3_ODI_Z	value: 0
# name: SIM_MAG3_FAIL	value: 0
# name: SIM_MAG3_SCALING	value: 1
# name: SIM_MAG3_ORIENT	value: 0
# name: SIM_MAG_SAVE_IDS	value: 1
# name: SIM_INIT_LAT_OFS	value: 0
# name: SIM_INIT_LON_OFS	value: 0
# name: SIM_INIT_ALT_OFS	value: 0
# name: SIM_GPS_LOG_NUM	value: 0
# name: SIM_GPS1_ENABLE	value: 1
# name: SIM_GPS1_LAG_MS	value: 100
# name: SIM_GPS1_TYPE	value: 1
# name: SIM_GPS1_BYTELOS	value: 0
# name: SIM_GPS1_NUMSATS	value: 10
# name: SIM_GPS1_GLTCH_X	value: 0
# name: SIM_GPS1_GLTCH_Y	value: 0
# name: SIM_GPS1_GLTCH_Z	value: 0
# name: SIM_GPS1_HZ	value: 5
# name: SIM_GPS1_DRFTALT	value: 0
# name: SIM_GPS1_POS_X	value: 0
# name: SIM_GPS1_POS_Y	value: 0
# name: SIM_GPS1_POS_Z	value: 0
# name: SIM_GPS1_NOISE	value: 0
# name: SIM_GPS1_LCKTIME	value: 0
# name: SIM_GPS1_ALT_OFS	value: 0
# name: SIM_GPS1_HDG	value: 0
# name: SIM_GPS1_ACC	value: 0
# name: SIM_GPS1_VERR_X	value: 0
# name: SIM_GPS1_VERR_Y	value: 0
# name: SIM_GPS1_VERR_Z	value: 0
# name: SIM_GPS1_JAM	value: 0
# name: SIM_GPS2_ENABLE	value: 0
# name: SIM_GPS3_ENABLE	value: 0
# name: SIM_GPS4_ENABLE	value: 0
# name: SIM_ODOM_ENABLE	value: 0
# name: SIM_LED_LAYOUT	value: 0
# name: SIM_THML_SCENARI	value: 0
# name: SIM_VICON_POS_X	value: 0
# name: SIM_VICON_POS_Y	value: 0
# name: SIM_VICON_POS_Z	value: 0
# name: SIM_VICON_GLIT_X	value: 0
# name: SIM_VICON_GLIT_Y	value: 0
# name: SIM_VICON_GLIT_Z	value: 0
# name: SIM_VICON_FAIL	value: 0
# name: SIM_VICON_YAW	value: 0
# name: SIM_VICON_YAWERR	value: 0
# name: SIM_VICON_TMASK	value: 3
# name: SIM_VICON_VGLI_X	value: 0
# name: SIM_VICON_VGLI_Y	value: 0
# name: SIM_VICON_VGLI_Z	value: 0
# name: SIM_RATE_HZ	value: 1200
# name: SIM_IMU_COUNT	value: 2
# name: SIM_FTOWESC_ENA	value: 0
# name: SIM_FTOWESC_POW	value: 4095
# name: SIM_RICH_ENABLE	value: 0
# name: SIM_RICH_CTRL	value: -1
# name: SIM_IE24_ENABLE	value: 0
# name: SIM_IE24_STATE	value: -1
# name: SIM_IE24_ERROR	value: 0
# name: SIM_BARO_COUNT	value: 2
# name: SIM_BARO_RND	value: 0
# name: SIM_BARO_DRIFT	value: 0
# name: SIM_BARO_DISABLE	value: 0
# name: SIM_BARO_GLITCH	value: 0
# name: SIM_BARO_FREEZE	value: 0
# name: SIM_BARO_DELAY	value: 0
# name: SIM_BARO_WCF_FWD	value: 0
# name: SIM_BARO_WCF_BAK	value: 0
# name: SIM_BARO_WCF_RGT	value: 0
# name: SIM_BARO_WCF_LFT	value: 0
# name: SIM_BARO_WCF_UP	value: 0
# name: SIM_BARO_WCF_DN	value: 0
# name: SIM_BAR2_RND	value: 0
# name: SIM_BAR2_DRIFT	value: 0
# name: SIM_BAR2_DISABLE	value: 0
# name: SIM_BAR2_GLITCH	value: 0
# name: SIM_BAR2_FREEZE	value: 0
# name: SIM_BAR2_DELAY	value: 0
# name: SIM_BAR2_WCF_FWD	value: 0
# name: SIM_BAR2_WCF_BAK	value: 0
# name: SIM_BAR2_WCF_RGT	value: 0
# name: SIM_BAR2_WCF_LFT	value: 0
# name: SIM_BAR2_WCF_UP	value: 0
# name: SIM_BAR2_WCF_DN	value: 0
# name: SIM_BAR3_RND	value: 0
# name: SIM_BAR3_DRIFT	value: 0
# name: SIM_BAR3_DISABLE	value: 0
# name: SIM_BAR3_GLITCH	value: 0
# name: SIM_BAR3_FREEZE	value: 0
# name: SIM_BAR3_DELAY	value: 0
# name: SIM_BAR3_WCF_FWD	value: 0
# name: SIM_BAR3_WCF_BAK	value: 0
# name: SIM_BAR3_WCF_RGT	value: 0
# name: SIM_BAR3_WCF_LFT	value: 0
# name: SIM_BAR3_WCF_UP	value: 0
# name: SIM_BAR3_WCF_DN	value: 0
# name: SIM_TIME_JITTER	value: 0
# name: SIM_ESC_TELEM	value: 1
# name: SIM_ESC_ARM_RPM	value: 0
# name: SIM_UART_LOSS	value: 0
# name: SIM_ARSPD_RND	value: 2
# name: SIM_ARSPD_OFS	value: 2013
# name: SIM_ARSPD_FAIL	value: 0
# name: SIM_ARSPD_FAILP	value: 0
# name: SIM_ARSPD_PITOT	value: 0
# name: SIM_ARSPD_SIGN	value: 0
# name: SIM_ARSPD_RATIO	value: 1
# name: SIM_ARSPD2_RND	value: 2
# name: SIM_ARSPD2_OFS	value: 2013
# name: SIM_ARSPD2_FAIL	value: 0
# name: SIM_ARSPD2_FAILP	value: 0
# name: SIM_ARSPD2_PITOT	value: 0
# name: SIM_ARSPD2_SIGN	value: 0
# name: SIM_ARSPD2_RATIO	value: 1
# name: SIM_ADSB_TYPES	value: 1
# name: SIM_TEMP_START	value: 25
# name: SIM_TEMP_BRD_OFF	value: 20
# name: SIM_TEMP_TCONST	value: 30
# name: SIM_TEMP_BFACTOR	value: 0
# name: SIM_WIND_DIR_Z	value: 0
# name: SIM_WIND_T	value: 0
# name: SIM_WIND_T_ALT	value: 60
# name: SIM_WIND_T_COEF	value: 0
# name: SIM_RC_CHANCOUNT	value: 16
# name: SIM_SPR_ENABLE	value: 0
# name: SIM_SPR_PUMP	value: -1
# name: SIM_SPR_SPIN	value: -1
# name: SIM_GRPS_ENABLE	value: 0
# name: SIM_GRPS_PIN	value: -1
# name: SIM_GRPS_GRAB	value: 2000
# name: SIM_GRPS_RELEASE	value: 1000
# name: SIM_GRPS_REVERSE	value: 0
# name: SIM_GRPE_ENABLE	value: 0
# name: SIM_GRPE_PIN	value: -1
# name: SIM_WOW_PIN	value: -1
# name: SIM_VIB_FREQ_X	value: 0
# name: SIM_VIB_FREQ_Y	value: 0
# name: SIM_VIB_FREQ_Z	value: 0
# name: SIM_PARA_ENABLE	value: 0
# name: SIM_PARA_PIN	value: -1
# name: SIM_BAUDLIMIT_EN	value: 0
# name: SIM_PLD_ENABLE	value: 0
# name: SIM_PLD_LAT	value: 0
# name: SIM_PLD_LON	value: 0
# name: SIM_PLD_HEIGHT	value: 0
# name: SIM_PLD_YAW	value: 0
# name: SIM_PLD_RATE	value: 100
# name: SIM_PLD_TYPE	value: 0
# name: SIM_PLD_ALT_LMT	value: 15
# name: SIM_PLD_DIST_LMT	value: 10
# name: SIM_PLD_ORIENT	value: 24
# name: SIM_PLD_OPTIONS	value: 0
# name: SIM_PLD_SHIP	value: 0
# name: SIM_SHOVE_X	value: 0
# name: SIM_SHOVE_Y	value: 0
# name: SIM_SHOVE_Z	value: 0
# name: SIM_SHOVE_TIME	value: 0
# name: SIM_FLOW_RND	value: 0
# name: SIM_TWIST_X	value: 0
# name: SIM_TWIST_Y	value: 0
# name: SIM_TWIST_Z	value: 0
# name: SIM_TWIST_TIME	value: 0
# name: SIM_GND_BEHAV	value: -1
# name: SIM_WAVE_ENABLE	value: 0
# name: SIM_WAVE_LENGTH	value: 10
# name: SIM_WAVE_AMP	value: 0
# name: SIM_WAVE_DIR	value: 0
# name: SIM_WAVE_SPEED	value: 0
# name: SIM_TIDE_DIR	value: 0
# name: SIM_TIDE_SPEED	value: 0
# name: SIM_OPOS_LAT	value: -35
# name: SIM_OPOS_LNG	value: 149
# name: SIM_OPOS_ALT	value: 584
# name: SIM_OPOS_HDG	value: 353
# name: SIM_LOOP_DELAY	value: 0
# name: SIM_TA_ENABLE	value: 1
# name: SIM_EFI_TYPE	value: 0
# name: SIM_VIB_MOT_HMNC	value: 1
# name: SIM_VIB_MOT_MASK	value: 0
# name: SIM_VIB_MOT_MAX	value: 0
# name: SIM_INS_THR_MIN	value: 0
# name: SIM_VIB_MOT_MULT	value: 1
# name: BARO1_GND_PRESS	value: 101325
# name: BARO_GND_TEMP	value: 0
# name: BARO_ALT_OFFSET	value: 0
# name: BARO_PRIMARY	value: 0
# name: BARO_EXT_BUS	value: -1
# name: BARO2_GND_PRESS	value: 101324
# name: BARO3_GND_PRESS	value: 0
# name: BARO_FLTR_RNG	value: 0
# name: BARO_PROBE_EXT	value: 0
# name: BARO1_DEVID	value: 65540
# name: BARO2_DEVID	value: 65796
# name: BARO3_DEVID	value: 0
# name: BARO1_WCF_ENABLE	value: 0
# name: BARO2_WCF_ENABLE	value: 0
# name: BARO3_WCF_ENABLE	value: 0
# name: BARO_FIELD_ELV	value: 0
# name: BARO_ALTERR_MAX	value: 2000
# name: BARO_OPTIONS	value: 0
# name: GPS_NAVFILTER	value: 8
# name: GPS_AUTO_SWITCH	value: 1
# name: GPS_SBAS_MODE	value: 2
# name: GPS_MIN_ELEV	value: -100
# name: GPS_INJECT_TO	value: 127
# name: GPS_SBP_LOGMASK	value: -256
# name: GPS_RAW_DATA	value: 0
# name: GPS_SAVE_CFG	value: 2
# name: GPS_AUTO_CONFIG	value: 1
# name: GPS_BLEND_MASK	value: 5
# name: GPS_DRV_OPTIONS	value: 0
# name: GPS_PRIMARY	value: 0
# name: GPS1_TYPE	value: 1
# name: GPS1_GNSS_MODE	value: 0
# name: GPS1_RATE_MS	value: 200
# name: GPS1_POS_X	value: 0
# name: GPS1_POS_Y	value: 0
# name: GPS1_POS_Z	value: 0
# name: GPS1_DELAY_MS	value: 0
# name: GPS1_COM_PORT	value: 1
# name: GPS1_MB_TYPE	value: 0
# name: GPS1_CAN_NODEID	value: 0
# name: GPS1_CAN_OVRIDE	value: 0
# name: GPS2_TYPE	value: 0
# name: SCHED_DEBUG	value: 0
# name: SCHED_LOOP_RATE	value: 400
# name: SCHED_OPTIONS	value: 0
# name: AVOID_ENABLE	value: 3
# name: AVOID_ANGLE_MAX	value: 1000
# name: AVOID_DIST_MAX	value: 5
# name: AVOID_MARGIN	value: 2
# name: AVOID_BEHAVE	value: 0
# name: AVOID_BACKUP_SPD	value: 0
# name: AVOID_ALT_MIN	value: 0
# name: AVOID_ACCEL_MAX	value: 3
# name: AVOID_BACKUP_DZ	value: 0
# name: AVOID_BACKZ_SPD	value: 0
# name: RALLY_TOTAL	value: 0
# name: RALLY_LIMIT_KM	value: 0
# name: RALLY_INCL_HOME	value: 1
# name: MOT_YAW_HEADROOM	value: 200
# name: MOT_THST_EXPO	value: 0
# name: MOT_SPIN_MAX	value: 0
# name: MOT_BAT_VOLT_MAX	value: 12
# name: MOT_BAT_VOLT_MIN	value: 9
# name: MOT_BAT_CURR_MAX	value: 0
# name: MOT_PWM_TYPE	value: 0
# name: MOT_PWM_MIN	value: 1000
# name: MOT_PWM_MAX	value: 2000
# name: MOT_SPIN_MIN	value: 0
# name: MOT_SPIN_ARM	value: 0
# name: MOT_BAT_CURR_TC	value: 5
# name: MOT_THST_HOVER	value: 0
# name: MOT_HOVER_LEARN	value: 2
# name: MOT_SAFE_DISARM	value: 0
# name: MOT_SPOOL_TIME	value: 0
# name: MOT_BOOST_SCALE	value: 0
# name: MOT_BAT_IDX	value: 0
# name: MOT_SLEW_UP_TIME	value: 0
# name: MOT_SLEW_DN_TIME	value: 0
# name: MOT_SAFE_TIME	value: 1
# name: MOT_OPTIONS	value: 0
# name: MOT_SPOOL_TIM_DN	value: 0
# name: RCMAP_ROLL	value: 1
# name: RCMAP_PITCH	value: 2
# name: RCMAP_THROTTLE	value: 3
# name: RCMAP_YAW	value: 4
# name: EK2_ENABLE	value: 0
# name: EK3_ENABLE	value: 1
# name: EK3_VELNE_M_NSE	value: 0
# name: EK3_VELD_M_NSE	value: 0
# name: EK3_VEL_I_GATE	value: 500
# name: EK3_POSNE_M_NSE	value: 0
# name: EK3_POS_I_GATE	value: 500
# name: EK3_GLITCH_RAD	value: 25
# name: EK3_ALT_M_NSE	value: 2
# name: EK3_HGT_I_GATE	value: 500
# name: EK3_HGT_DELAY	value: 60
# name: EK3_MAG_M_NSE	value: 0
# name: EK3_MAG_CAL	value: 3
# name: EK3_MAG_I_GATE	value: 300
# name: EK3_EAS_M_NSE	value: 1
# name: EK3_EAS_I_GATE	value: 400
# name: EK3_RNG_M_NSE	value: 0
# name: EK3_RNG_I_GATE	value: 500
# name: EK3_MAX_FLOW	value: 2
# name: EK3_FLOW_M_NSE	value: 0
# name: EK3_FLOW_I_GATE	value: 300
# name: EK3_FLOW_DELAY	value: 10
# name: EK3_GYRO_P_NSE	value: 0
# name: EK3_ACC_P_NSE	value: 0
# name: EK3_GBIAS_P_NSE	value: 0
# name: EK3_ABIAS_P_NSE	value: 0
# name: EK3_WIND_P_NSE	value: 0
# name: EK3_WIND_PSCALE	value: 1
# name: EK3_GPS_CHECK	value: 31
# name: EK3_IMU_MASK	value: 3
# name: EK3_CHECK_SCALE	value: 100
# name: EK3_NOAID_M_NSE	value: 10
# name: EK3_BETA_MASK	value: 0
# name: EK3_YAW_M_NSE	value: 0
# name: EK3_YAW_I_GATE	value: 300
# name: EK3_TAU_OUTPUT	value: 25
# name: EK3_MAGE_P_NSE	value: 0
# name: EK3_MAGB_P_NSE	value: 0
# name: EK3_RNG_USE_HGT	value: -1
# name: EK3_TERR_GRAD	value: 0
# name: EK3_BCN_M_NSE	value: 1
# name: EK3_BCN_I_GTE	value: 500
# name: EK3_BCN_DELAY	value: 50
# name: EK3_RNG_USE_SPD	value: 2
# name: EK3_ACC_BIAS_LIM	value: 1
# name: EK3_MAG_MASK	value: 0
# name: EK3_OGN_HGT_MASK	value: 0
# name: EK3_VIS_VERR_MIN	value: 0
# name: EK3_VIS_VERR_MAX	value: 0
# name: EK3_WENC_VERR	value: 0
# name: EK3_FLOW_USE	value: 1
# name: EK3_HRT_FILT	value: 2
# name: EK3_MAG_EF_LIM	value: 50
# name: EK3_GSF_RUN_MASK	value: 3
# name: EK3_GSF_USE_MASK	value: 3
# name: EK3_GSF_RST_MAX	value: 2
# name: EK3_ERR_THRESH	value: 0
# name: EK3_AFFINITY	value: 0
# name: EK3_SRC1_POSXY	value: 3
# name: EK3_SRC1_VELXY	value: 3
# name: EK3_SRC1_POSZ	value: 1
# name: EK3_SRC1_VELZ	value: 3
# name: EK3_SRC1_YAW	value: 1
# name: EK3_SRC2_POSXY	value: 0
# name: EK3_SRC2_VELXY	value: 0
# name: EK3_SRC2_POSZ	value: 1
# name: EK3_SRC2_VELZ	value: 0
# name: EK3_SRC2_YAW	value: 0
# name: EK3_SRC3_POSXY	value: 0
# name: EK3_SRC3_VELXY	value: 0
# name: EK3_SRC3_POSZ	value: 1
# name: EK3_SRC3_VELZ	value: 0
# name: EK3_SRC3_YAW	value: 0
# name: EK3_SRC_OPTIONS	value: 1
# name: EK3_DRAG_BCOEF_X	value: 0
# name: EK3_DRAG_BCOEF_Y	value: 0
# name: EK3_DRAG_M_NSE	value: 0
# name: EK3_DRAG_MCOEF	value: 0
# name: EK3_OGNM_TEST_SF	value: 2
# name: EK3_GND_EFF_DZ	value: 4
# name: EK3_PRIMARY	value: 0
# name: EK3_LOG_LEVEL	value: 0
# name: EK3_GPS_VACC_MAX	value: 0
# name: EK3_OPTIONS	value: 0
# name: MIS_TOTAL	value: 0
# name: MIS_RESTART	value: 0
# name: MIS_OPTIONS	value: 0
# name: RSSI_TYPE	value: 0
# name: RNGFND1_TYPE	value: 0
# name: RNGFND2_TYPE	value: 0
# name: RNGFND3_TYPE	value: 0
# name: RNGFND4_TYPE	value: 0
# name: RNGFND5_TYPE	value: 0
# name: RNGFND6_TYPE	value: 0
# name: RNGFND7_TYPE	value: 0
# name: RNGFND8_TYPE	value: 0
# name: RNGFND9_TYPE	value: 0
# name: RNGFNDA_TYPE	value: 0
# name: TERRAIN_ENABLE	value: 1
# name: TERRAIN_SPACING	value: 100
# name: TERRAIN_OPTIONS	value: 0
# name: TERRAIN_MARGIN	value: 0
# name: TERRAIN_OFS_MAX	value: 30
# name: TERRAIN_CACHE_SZ	value: 12
# name: FLOW_TYPE	value: 0
# name: PLND_ENABLED	value: 0
# name: RPM1_TYPE	value: 0
# name: RPM2_TYPE	value: 0
# name: ADSB_TYPE	value: 0
# name: AVD_ENABLE	value: 0
# name: NTF_LED_BRIGHT	value: 3
# name: NTF_BUZZ_TYPES	value: 5
# name: NTF_LED_OVERRIDE	value: 0
# name: NTF_DISPLAY_TYPE	value: 0
# name: NTF_BUZZ_PIN	value: -1
# name: NTF_LED_TYPES	value: 123079
# name: NTF_BUZZ_ON_LVL	value: 1
# name: NTF_BUZZ_VOLUME	value: 100
# name: NTF_LED_LEN	value: 1
# name: THROW_MOT_START	value: 0
# name: THROW_ALT_MIN	value: 0
# name: THROW_ALT_MAX	value: 0
# name: OSD_TYPE	value: 0
# name: CC_TYPE	value: 0
# name: WP_NAVALT_MIN	value: 0
# name: BTN_ENABLE	value: 0
# name: THROW_NEXTMODE	value: 18
# name: THROW_TYPE	value: 0
# name: GND_EFFECT_COMP	value: 1
# name: DEV_OPTIONS	value: 0
# name: BCN_TYPE	value: 0
# name: PRX_IGN_GND	value: 0
# name: PRX_LOG_RAW	value: 0
# name: PRX_FILT	value: 0
# name: PRX_ALT_MIN	value: 1
# name: PRX1_TYPE	value: 0
# name: PRX2_TYPE	value: 0
# name: PRX3_TYPE	value: 0
# name: ACRO_THR_MID	value: 0
# name: SYSID_ENFORCE	value: 0
# name: FRAME_CLASS	value: 1
# name: SERVO1_MIN	value: 1100
# name: SERVO1_MAX	value: 1900
# name: SERVO1_TRIM	value: 1500
# name: SERVO1_REVERSED	value: 0
# name: SERVO1_FUNCTION	value: 33
# name: SERVO2_MIN	value: 1100
# name: SERVO2_MAX	value: 1900
# name: SERVO2_TRIM	value: 1500
# name: SERVO2_REVERSED	value: 0
# name: SERVO2_FUNCTION	value: 34
# name: SERVO3_MIN	value: 1100
# name: SERVO3_MAX	value: 1900
# name: SERVO3_TRIM	value: 1500
# name: SERVO3_REVERSED	value: 0
# name: SERVO3_FUNCTION	value: 35
# name: SERVO4_MIN	value: 1100
# name: SERVO4_MAX	value: 1900
# name: SERVO4_TRIM	value: 1500
# name: SERVO4_REVERSED	value: 0
# name: SERVO4_FUNCTION	value: 36
# name: SERVO5_MIN	value: 1100
# name: SERVO5_MAX	value: 1900
# name: SERVO5_TRIM	value: 1500
# name: SERVO5_REVERSED	value: 0
# name: SERVO5_FUNCTION	value: 0
# name: SERVO6_MIN	value: 1100
# name: SERVO6_MAX	value: 1900
# name: SERVO6_TRIM	value: 1500
# name: SERVO6_REVERSED	value: 0
# name: SERVO6_FUNCTION	value: 0
# name: SERVO7_MIN	value: 1100
# name: SERVO7_MAX	value: 1900
# name: SERVO7_TRIM	value: 1500
# name: SERVO7_REVERSED	value: 0
# name: SERVO7_FUNCTION	value: 0
# name: SERVO8_MIN	value: 1100
# name: SERVO8_MAX	value: 1900
# name: SERVO8_TRIM	value: 1500
# name: SERVO8_REVERSED	value: 0
# name: SERVO8_FUNCTION	value: 0
# name: SERVO9_MIN	value: 1100
# name: SERVO9_MAX	value: 1900
# name: SERVO9_TRIM	value: 1500
# name: SERVO9_REVERSED	value: 0
# name: SERVO9_FUNCTION	value: 0
# name: SERVO10_MIN	value: 1100
# name: SERVO10_MAX	value: 1900
# name: SERVO10_TRIM	value: 1500
# name: SERVO10_REVERSED	value: 0
# name: SERVO10_FUNCTION	value: 0
# name: SERVO11_MIN	value: 1100
# name: SERVO11_MAX	value: 1900
# name: SERVO11_TRIM	value: 1500
# name: SERVO11_REVERSED	value: 0
# name: SERVO11_FUNCTION	value: 0
# name: SERVO12_MIN	value: 1100
# name: SERVO12_MAX	value: 1900
# name: SERVO12_TRIM	value: 1500
# name: SERVO12_REVERSED	value: 0
# name: SERVO12_FUNCTION	value: 0
# name: SERVO13_MIN	value: 1100
# name: SERVO13_MAX	value: 1900
# name: SERVO13_TRIM	value: 1500
# name: SERVO13_REVERSED	value: 0
# name: SERVO13_FUNCTION	value: 0
# name: SERVO14_MIN	value: 1100
# name: SERVO14_MAX	value: 1900
# name: SERVO14_TRIM	value: 1500
# name: SERVO14_REVERSED	value: 0
# name: SERVO14_FUNCTION	value: 0
# name: SERVO15_MIN	value: 1100
# name: SERVO15_MAX	value: 1900
# name: SERVO15_TRIM	value: 1500
# name: SERVO15_REVERSED	value: 0
# name: SERVO15_FUNCTION	value: 0
# name: SERVO16_MIN	value: 1100
# name: SERVO16_MAX	value: 1900
# name: SERVO16_TRIM	value: 1500
# name: SERVO16_REVERSED	value: 0
# name: SERVO16_FUNCTION	value: 0
# name: SERVO_RATE	value: 50
# name: SERVO_VOLZ_MASK	value: 0
# name: SERVO_VOLZ_RANGE	value: 200
# name: SERVO_SBUS_RATE	value: 50
# name: SERVO_ROB_POSMIN	value: 0
# name: SERVO_ROB_POSMAX	value: 4095
# name: SERVO_FTW_MASK	value: 0
# name: SERVO_FTW_RVMASK	value: 0
# name: SERVO_FTW_POLES	value: 14
# name: SERVO_DSHOT_RATE	value: 0
# name: SERVO_DSHOT_ESC	value: 0
# name: SERVO_GPIO_MASK	value: 0
# name: SERVO_RC_FS_MSK	value: 0
# name: SERVO_32_ENABLE	value: 0
# name: RC1_MIN	value: 1000
# name: RC1_TRIM	value: 1500
# name: RC1_MAX	value: 2000
# name: RC1_REVERSED	value: 0
# name: RC1_DZ	value: 20
# name: RC1_OPTION	value: 0
# name: RC2_MIN	value: 1000
# name: RC2_TRIM	value: 1500
# name: RC2_MAX	value: 2000
# name: RC2_REVERSED	value: 0
# name: RC2_DZ	value: 20
# name: RC2_OPTION	value: 0
# name: RC3_MIN	value: 1000
# name: RC3_TRIM	value: 1500
# name: RC3_MAX	value: 2000
# name: RC3_REVERSED	value: 0
# name: RC3_DZ	value: 30
# name: RC3_OPTION	value: 0
# name: RC4_MIN	value: 1000
# name: RC4_TRIM	value: 1500
# name: RC4_MAX	value: 2000
# name: RC4_REVERSED	value: 0
# name: RC4_DZ	value: 20
# name: RC4_OPTION	value: 0
# name: RC5_MIN	value: 1000
# name: RC5_TRIM	value: 1500
# name: RC5_MAX	value: 2000
# name: RC5_REVERSED	value: 0
# name: RC5_DZ	value: 0
# name: RC5_OPTION	value: 0
# name: RC6_MIN	value: 1000
# name: RC6_TRIM	value: 1500
# name: RC6_MAX	value: 2000
# name: RC6_REVERSED	value: 0
# name: RC6_DZ	value: 0
# name: RC6_OPTION	value: 0
# name: RC7_MIN	value: 1000
# name: RC7_TRIM	value: 1500
# name: RC7_MAX	value: 2000
# name: RC7_REVERSED	value: 0
# name: RC7_DZ	value: 0
# name: RC7_OPTION	value: 7
# name: RC8_MIN	value: 1000
# name: RC8_TRIM	value: 1500
# name: RC8_MAX	value: 2000
# name: RC8_REVERSED	value: 0
# name: RC8_DZ	value: 0
# name: RC8_OPTION	value: 0
# name: RC9_MIN	value: 1100
# name: RC9_TRIM	value: 1500
# name: RC9_MAX	value: 1900
# name: RC9_REVERSED	value: 0
# name: RC9_DZ	value: 0
# name: RC9_OPTION	value: 0
# name: RC10_MIN	value: 1100
# name: RC10_TRIM	value: 1500
# name: RC10_MAX	value: 1900
# name: RC10_REVERSED	value: 0
# name: RC10_DZ	value: 0
# name: RC10_OPTION	value: 0
# name: RC11_MIN	value: 1100
# name: RC11_TRIM	value: 1500
# name: RC11_MAX	value: 1900
# name: RC11_REVERSED	value: 0
# name: RC11_DZ	value: 0
# name: RC11_OPTION	value: 0
# name: RC12_MIN	value: 1100
# name: RC12_TRIM	value: 1500
# name: RC12_MAX	value: 1900
# name: RC12_REVERSED	value: 0
# name: RC12_DZ	value: 0
# name: RC12_OPTION	value: 0
# name: RC13_MIN	value: 1100
# name: RC13_TRIM	value: 1500
# name: RC13_MAX	value: 1900
# name: RC13_REVERSED	value: 0
# name: RC13_DZ	value: 0
# name: RC13_OPTION	value: 0
# name: RC14_MIN	value: 1100
# name: RC14_TRIM	value: 1500
# name: RC14_MAX	value: 1900
# name: RC14_REVERSED	value: 0
# name: RC14_DZ	value: 0
# name: RC14_OPTION	value: 0
# name: RC15_MIN	value: 1100
# name: RC15_TRIM	value: 1500
# name: RC15_MAX	value: 1900
# name: RC15_REVERSED	value: 0
# name: RC15_DZ	value: 0
# name: RC15_OPTION	value: 0
# name: RC16_MIN	value: 1100
# name: RC16_TRIM	value: 1500
# name: RC16_MAX	value: 1900
# name: RC16_REVERSED	value: 0
# name: RC16_DZ	value: 0
# name: RC16_OPTION	value: 0
# name: RC_OVERRIDE_TIME	value: 3
# name: RC_OPTIONS	value: 32
# name: RC_PROTOCOLS	value: 1
# name: RC_FS_TIMEOUT	value: 1
# name: TCAL_ENABLED	value: 0
# name: SRTL_ACCURACY	value: 2
# name: SRTL_POINTS	value: 300
# name: SRTL_OPTIONS	value: 0
# name: WINCH_TYPE	value: 0
# name: PILOT_SPEED_DN	value: 0
# name: LAND_ALT_LOW	value: 1000
# name: FHLD_XY_P	value: 0
# name: FHLD_XY_I	value: 0
# name: FHLD_XY_IMAX	value: 3000
# name: FHLD_XY_FILT_HZ	value: 5
# name: FHLD_FLOW_MAX	value: 0
# name: FHLD_FILT_HZ	value: 5
# name: FHLD_QUAL_MIN	value: 10
# name: FHLD_BRAKE_RATE	value: 8
# name: FOLL_ENABLE	value: 0
# name: AUTOTUNE_AXES	value: 7
# name: AUTOTUNE_AGGR	value: 0
# name: AUTOTUNE_MIN_D	value: 0
# name: TUNE_MIN	value: 0
# name: TUNE_MAX	value: 0
# name: OA_TYPE	value: 0
# name: SID_AXIS	value: 0
# name: FS_VIBE_ENABLE	value: 1
# name: FS_OPTIONS	value: 16
# name: ZIGZ_AUTO_ENABLE	value: 0
# name: ACRO_OPTIONS	value: 0
# name: AUTO_OPTIONS	value: 0
# name: GUID_OPTIONS	value: 0
# name: FS_GCS_TIMEOUT	value: 5
# name: RTL_OPTIONS	value: 0
# name: FLIGHT_OPTIONS	value: 0
# name: RNGFND_FILT	value: 0
# name: GUID_TIMEOUT	value: 3
# name: SURFTRAK_MODE	value: 1
# name: FS_DR_ENABLE	value: 2
# name: FS_DR_TIMEOUT	value: 30
# name: ACRO_RP_RATE	value: 360
# name: ACRO_RP_EXPO	value: 0
# name: ACRO_RP_RATE_TC	value: 0
# name: ACRO_Y_RATE	value: 202
# name: ACRO_Y_EXPO	value: 0
# name: ACRO_Y_RATE_TC	value: 0
# name: PILOT_Y_RATE	value: 202
# name: PILOT_Y_EXPO	value: 0
# name: PILOT_Y_RATE_TC	value: 0
# name: TKOFF_SLEW_TIME	value: 2
# name: TKOFF_RPM_MIN	value: 0
# name: WVANE_ENABLE	value: 0
# name: PLDP_THRESH	value: 0
# name: PLDP_RNG_MAX	value: 0
# name: PLDP_DELAY	value: 0
# name: PLDP_SPEED_DN	value: 0
# name: SURFTRAK_TC	value: 1
# name: TKOFF_THR_MAX	value: 0
# name: TKOFF_RPM_MAX	value: 0
# name: FS_EKF_FILT	value: 5
# name: FSTRATE_ENABLE	value: 0
# name: FSTRATE_DIV	value: 1
# name: FFT_ENABLE	value: 0
# name: VISO_TYPE	value: 0
# name: VTX_ENABLE	value: 0
# name: MSP_OSD_NCELLS	value: 0
# name: MSP_OPTIONS	value: 0
# name: FRSKY_UPLINK_ID	value: 13
# name: FRSKY_DNLINK1_ID	value: 20
# name: FRSKY_DNLINK2_ID	value: 7
# name: FRSKY_DNLINK_ID	value: 27
# name: FRSKY_OPTIONS	value: 0
# name: GEN_TYPE	value: 0
# name: EAHRS_TYPE	value: 0
# name: EFI_TYPE	value: 0
# name: ARSPD_ENABLE	value: 0
# name: CUST_ROT_ENABLE	value: 0
# name: ESC_TLM_MAV_OFS	value: 0
# name: FENCE_ENABLE	value: 0
# name: FENCE_TYPE	value: 7
# name: FENCE_ACTION	value: 1
# name: FENCE_ALT_MAX	value: 100
# name: FENCE_RADIUS	value: 150
# name: FENCE_MARGIN	value: 2
# name: FENCE_TOTAL	value: 0
# name: FENCE_ALT_MIN	value: -10
# name: FENCE_AUTOENABLE	value: 0
# name: FENCE_OPTIONS	value: 0
# name: DID_ENABLE	value: 0
# name: TEMP_LOG	value: 0
# name: TEMP1_TYPE	value: 0
# name: TEMP2_TYPE	value: 0
# name: TEMP3_TYPE	value: 0
# name: NMEA_RATE_MS	value: 100
# name: NMEA_MSG_EN	value: 3
# name: KDE_NPOLE	value: 14
# name: FLTMODE_GCSBLOCK	value: 0
# name: NET_ENABLE	value: 0
# name: NET_P1_TYPE	value: 0
# name: NET_P2_TYPE	value: 0
# name: NET_P3_TYPE	value: 0
# name: NET_P4_TYPE	value: 0
# name: FILT1_TYPE	value: 0
# name: FILT2_TYPE	value: 0
# name: FILT3_TYPE	value: 0
# name: FILT4_TYPE	value: 0
# name: FILT5_TYPE	value: 0
# name: FILT6_TYPE	value: 0
# name: FILT7_TYPE	value: 0
# name: FILT8_TYPE	value: 0
# name: STAT_BOOTCNT	value: 1
# name: STAT_FLTTIME	value: 0
# name: STAT_RUNTIME	value: 1766
# name: STAT_RESET	value: 1
# name: SCR_ENABLE	value: 0
# name: LOG_BACKEND_TYPE	value: 1
# name: LOG_FILE_BUFSIZE	value: 200
# name: LOG_DISARMED	value: 0
# name: LOG_REPLAY	value: 0
# name: LOG_FILE_DSRMROT	value: 0
# name: LOG_MAV_BUFSIZE	value: 8
# name: LOG_FILE_TIMEOUT	value: 5
# name: LOG_FILE_MB_FREE	value: 500
# name: LOG_FILE_RATEMAX	value: 0
# name: LOG_MAV_RATEMAX	value: 0
# name: LOG_BLK_RATEMAX	value: 0
# name: LOG_DARM_RATEMAX	value: 0
# name: LOG_MAX_FILES	value: 500
# name: GRIP_ENABLE	value: 0
# name: SERIAL0_BAUD	value: 115
# name: SERIAL0_PROTOCOL	value: 2
# name: SERIAL1_PROTOCOL	value: 2
# name: SERIAL1_BAUD	value: 57
# name: SERIAL2_PROTOCOL	value: 2
# name: SERIAL2_BAUD	value: 57
# name: SERIAL3_PROTOCOL	value: 5
# name: SERIAL3_BAUD	value: 230
# name: SERIAL4_PROTOCOL	value: 5
# name: SERIAL4_BAUD	value: 230
# name: SERIAL5_PROTOCOL	value: -1
# name: SERIAL5_BAUD	value: 57
# name: SERIAL6_PROTOCOL	value: -1
# name: SERIAL6_BAUD	value: 57
# name: SERIAL1_OPTIONS	value: 0
# name: SERIAL2_OPTIONS	value: 0
# name: SERIAL3_OPTIONS	value: 0
# name: SERIAL4_OPTIONS	value: 0
# name: SERIAL5_OPTIONS	value: 0
# name: SERIAL6_OPTIONS	value: 0
# name: SERIAL_PASS1	value: 0
# name: SERIAL_PASS2	value: -1
# name: SERIAL_PASSTIMO	value: 15
# name: SERIAL7_PROTOCOL	value: -1
# name: SERIAL7_BAUD	value: 57
# name: SERIAL7_OPTIONS	value: 0
# name: STAT_RUNTIME	value: 1797
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[80], line 7
#       5 time.sleep(0.01)
#       6 try:
# ----> 7     message = master.recv_match(type='PARAM_VALUE', blocking=True).to_dict()
#       8     print('name: %s\tvalue: %d' % (message['param_id'],
#       9                                    message['param_value']))
#      10 except Exception as error:
#
# File ~/.local/lib/python3.10/site-packages/pymavlink/mavutil.py:526, in mavfile.recv_match(self, condition, type, blocking, timeout)
#     524     hook(self)
#     525 if timeout is None:
# --> 526     self.select(0.05)
#     527 else:
#     528     self.select(timeout/2)
#
# File ~/.local/lib/python3.10/site-packages/pymavlink/mavutil.py:339, in mavfile.select(self, timeout)
#     337     return True
#     338 try:
# --> 339     (rin, win, xin) = select.select([self.fd], [], [], timeout)
#     340 except select.error:
#     341     return False
#
# KeyboardInterrupt:

# %% [markdown]
# ### Read and write parameters
#
# Ici on va changer un paramètre de l'EEPROM qui définit le comportement de notre autopilote.

# %%
# Request parameter
master.mav.param_request_read_send(
    master.target_system, master.target_component,
    b'LAND_SPEED',
    -1
)

# Print old parameter value
message = master.recv_match(type='PARAM_VALUE', blocking=True).to_dict()
print('name: %s\nvalue: %d' %
      (message['param_id'], message['param_value']))

time.sleep(1)
# Out:
# name: LAND_SPEED
# value: 50

# %%
# Set parameter value
# Set a parameter value TEMPORARILY to RAM. It will be reset to default on system reboot.
# Send the ACTION MAV_ACTION_STORAGE_WRITE to PERMANENTLY write the RAM contents to EEPROM.
# The parameter variable type is described by MAV_PARAM_TYPE in http://mavlink.org/messages/common.
master.mav.param_set_send(
    master.target_system, master.target_component,
    b'LAND_SPEED',
    5,
    mavutil.mavlink.MAV_PARAM_TYPE_REAL32
)

# Read ACK
# IMPORTANT: The receiving component should acknowledge the new parameter value by sending a
# param_value message to all communication partners.
# This will also ensure that multiple GCS all have an up-to-date list of all parameters.
# If the sending GCS did not receive a PARAM_VALUE message within its timeout time,
# it should re-send the PARAM_SET message.
message = master.recv_match(type='PARAM_VALUE', blocking=True).to_dict()
print('name: %s\nvalue: %d' %
      (message['param_id'], message['param_value']))

time.sleep(1)
# Out:
# name: LAND_SPEED
# value: 5

# %%
# Request parameter value to confirm
master.mav.param_request_read_send(
    master.target_system, master.target_component,
    b'LAND_SPEED',
    -1
)

# Print new value in RAM
message = master.recv_match(type='PARAM_VALUE', blocking=True).to_dict()
print('name: %s\nvalue: %d' %
      (message['param_id'], message['param_value']))
# Out:
# name: LAND_SPEED
# value: 5

# %% [markdown]
# ### Recevoir des données et les triées par type de messaeges

# %%
# You can also filter within recv_match command - see "Read all parameters" example
while True:
    msg = master.recv_match()
    if not msg:
        continue
    if msg.get_type() == 'HEARTBEAT':
        print("\n\n*****Got message: %s*****" % msg.get_type())
        print("Message: %s" % msg)
        print("\nAs dictionary: %s" % msg.to_dict())
        # Armed = MAV_STATE_STANDBY (4), Disarmed = MAV_STATE_ACTIVE (3)
        print("\nSystem status: %s" % msg.system_status)
    time.sleep(0.1)
# Out:
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# ...
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 192, custom_mode : 0, system_status : 4, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 192, 'custom_mode': 0, 'system_status': 4, 'mavlink_version': 3}
#
# System status: 4
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 2, autopilot : 3, base_mode : 81, custom_mode : 0, system_status : 3, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 2, 'autopilot': 3, 'base_mode': 81, 'custom_mode': 0, 'system_status': 3, 'mavlink_version': 3}
#
# System status: 3
#
#
# *****Got message: HEARTBEAT*****
# Message: HEARTBEAT {type : 6, autopilot : 8, base_mode : 0, custom_mode : 0, system_status : 0, mavlink_version : 3}
#
# As dictionary: {'mavpackettype': 'HEARTBEAT', 'type': 6, 'autopilot': 8, 'base_mode': 0, 'custom_mode': 0, 'system_status': 0, 'mavlink_version': 3}
#
# System status: 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[81], line 12
#      10     # Armed = MAV_STATE_STANDBY (4), Disarmed = MAV_STATE_ACTIVE (3)
#      11     print("\nSystem status: %s" % msg.system_status)
# ---> 12 time.sleep(0.1)
#
# KeyboardInterrupt:
